# %%
print("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Bar Graph

# %%
bar_labels=['a','b','c','d']
bar_heights=[3,4,7,2]
plt.bar(bar_labels,bar_heights)
plt.show()
